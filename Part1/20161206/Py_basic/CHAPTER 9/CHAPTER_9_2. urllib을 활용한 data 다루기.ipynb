# %% [markdown]
# ## 9.2 urllib 모듈을 활용한 Web 상의 데이터 다루기

# %%
import urllib.request
url = "http://storage.googleapis.com/patents/grant_full_text/2014/ipg140107.zip"
print("Start Download")
fname, headers = urllib.request.urlretrieve(url, 'ipg140107.zip')
print("fname : {0}, headers : {1}".format(fname, headers))
print("End Download")
# Out:
# Start Download
# fname : ipg140107.zip, headers : X-GUploader-UploadID: AEnB2Urkr5SxzvC26LwUb2OLlFdH7JiLfP7T17VDRcrRjiL_EAbwpT8d5qLRucOofMQR5fDiRhE5cQ9gLw_4I2is49gHTZuytw
# Expires: Tue, 06 Dec 2016 04:22:03 GMT
# Date: Tue, 06 Dec 2016 03:22:03 GMT
# Cache-Control: public, max-age=3600
# Last-Modified: Sat, 24 Jan 2015 12:27:22 GMT
# ETag: "4dda71c6e9f18712dcc4b736d7f4e8a9"
# x-goog-generation: 1422102442776000
# x-goog-metageneration: 1
# x-goog-stored-content-encoding: identity
# x-goog-stored-content-length: 107892419
# Content-Type: application/octet-stream
# x-goog-hash: crc32c=XZPA0A==
# x-goog-hash: md5=TdpxxunxhxLcxLc21/ToqQ==
# x-goog-storage-class: STANDARD
# Accept-Ranges: bytes
# Content-Length: 107892419
# Server: UploadServer
# Connection: close
#
#
# End Download

# %% [markdown]
# ## HTML Parsing을 이용한 자동화 하기

# %%
import re
import urllib.request

url = "https://goo.gl/U7mSQl"
html = urllib.request.urlopen(url)
html_contents = str(html.read())
print(html_contents)
id_results = re.findall(r"([A-Za-z0-9]+\*\*\*)", html_contents)  # 패턴과 일치하는 모든 데이터를 찾아라.
for result in id_results:
    print(result)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" ?>\r\n<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">\r\n\r\n<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ko">\r\n\r\n<head>\r\n\t<title>\xe2\x96\xb6 \xec\x95\x84\xec\x9d\xb4\xed\x85\x9c\xeb\xa7\xa4\xeb\x8b\x88\xec\x95\x84 \xe2\x97\x80 ::: \xea\xb3\xb5\xec\xa7\x80\xec\x82\xac\xed\x95\xad</title>\r\n\t<meta http-equiv="Content-Type" content="text/html;charset=UTF-8" />\r\n\t<meta name="Copyright" content="2002~2008 itemmania" />\r\n\t<meta http-equiv="Imagetoolbar" content="No" />\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=7" />\r\n\t<!--[if lte IE 6]>\r\n\t\t<link type="text/css" rel="stylesheet" href="/_css/_common_ie6.css" />\r\n\t\t<link type="text/css" rel="stylesheet" href="/_css/_style_ie6.css" />\r\n\t<![endif]-->\r\n\t<!--[if gt IE 6]>\r\n\t\t<link type="text/css" rel="stylesheet" href="/_css/_common.css" />\r\n\t\t<link type="text/css" rel="stylesheet" href="/_css/_style
# ...

# %%
import urllib.request
import re

url = "http://www.google.com/googlebooks/uspto-patents-grants-text.html"
html = urllib.request.urlopen(url)
html_contents = str(html.read().decode("utf-8")) #html 파일 읽고, 문자열로 변환

url_list = re.findall(r"(http)(.+)(zip)", html_contents)
for url in url_list:
    print("".join(url)) # 출력된 Tuple 형태 데이터 str으로 join
# Out:
# http://storage.googleapis.com/patents/grant_full_text/2015/ipg150106.zip
# http://storage.googleapis.com/patents/grant_full_text/2015/ipg150113.zip
# http://storage.googleapis.com/patents/grant_full_text/2015/ipg150120.zip
# http://storage.googleapis.com/patents/grant_full_text/2015/ipg150127.zip
# http://storage.googleapis.com/patents/grant_full_text/2015/ipg150203.zip
# http://storage.googleapis.com/patents/grant_full_text/2015/ipg150210.zip
# http://storage.googleapis.com/patents/grant_full_text/2015/ipg150217.zip
# http://storage.googleapis.com/patents/grant_full_text/2015/ipg150224.zip
# http://storage.googleapis.com/patents/grant_full_text/2015/ipg150303.zip
# http://storage.googleapis.com/patents/grant_full_text/2015/ipg150310.zip
# http://storage.googleapis.com/patents/grant_full_text/2015/ipg150317.zip
# http://storage.googleapis.com/patents/grant_full_text/2014/ipg140107.zip
# http://storage.googleapis.com/patents/grant_full_text/2014/ipg140114.zip
# ...

# %%
import urllib.request
import re

base_url = "http://web.eecs.umich.edu/~radev/coursera-slides/"
html = urllib.request.urlopen(base_url)
html_contents = str(html.read().decode("utf-8"))

url_list = re.findall(r"nlp[0-9a-zA-Z\_\.]*\.pdf", html_contents)
print("Start DownLoad")
for url in url_list:
    file_name = "".join(url)
    full_url = base_url + file_name
    print(full_url)
    fname, header = urllib.request.urlretrieve(full_url, file_name)
    print("End DownLoad")

# %%
import urllib.request
import re

url = "http://finance.naver.com/item/main.nhn?code=005930"
html = urllib.request.urlopen(url)
html_contents = str(html.read().decode("ms949"))

stock_results = re.findall("(\<dl class=\"blind\"\>)([\s\S]+?)(\<\/dl\>)",html_contents)
print("stock_results:{0}".format(stock_results))
print("------------------------------------------------------------------------------------------------------")
samsung_stock = stock_results[0] # 두 개 tuple 값중 첫번째 팬턴
samsung_index = samsung_stock[1] # 세 개의 tuple 값중 두 번째 값
index_list = re.findall("(\<dd\>)([\s\S]+?)(\<\/dd\>)", samsung_index)
print("index_lsit:{0}".format(index_list))
print("------------------------------------------------------------------------------------------------------")
for index in index_list:
    print(index[1])   # 세 개의 tuple 값중 두 번째 값
# Out:
# stock_results:[('<dl class="blind">', ' \n\t        <dt>종목 시세 정보</dt> \n\t        <dd>2016년 12월 02일 16시 10분 기준 장마감</dd> \n\t        <dd>종목명 삼성전자</dd> \n\t        <dd>종목코드 005930 코스피</dd> \n\t        <dd>현재가 1,727,000 전일대비 하락 22,000 마이너스 1.26 퍼센트</dd> \n\t        <dd>전일가 1,749,000</dd> \n\t        <dd>시가 1,724,000</dd> \n\t        <dd>고가 1,738,000</dd> \n\t        <dd>상한가 2,273,000</dd> \n\t        <dd>저가 1,707,000</dd> \n\t        <dd>하한가 1,225,000</dd> \n\t        <dd>거래량 281,221</dd> \n\t        <dd>거래대금 483,838백만</dd> \n        ', '</dl>'), ('<dl class="blind">', ' \n                        <dt><strong>삼성전자</strong></dt> \n                        <dd>오늘의시세 1,727,000 포인트</dd> \n                        <dd>22,000 포인트 하락</dd> \n                        <dd>1.26% 마이너스</dd> \n                ', '</dl>')]
# ------------------------------------------------------------------------------------------------------
# ...
